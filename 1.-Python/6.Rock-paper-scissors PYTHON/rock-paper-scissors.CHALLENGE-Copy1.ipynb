# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left">

# %% [markdown]
# # Rock, Paper & Scissors
#
# Let's play the famous game against our computer. You can check the rules [here](https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors).
#
# ## Task
# Create a program that imitates the playability of the well known game of rock, paper, scissors. Follow the guidelines provided.
#
# ## Tools
# 1. Loop: **for/while**
# 2. Functions: **input(), print()...**
# 3. Conditional statements: **if, elif, else**
# 4. Definition of functions. Modular programming
# 5. Import modules
#
# **To solve this challenge, the use of functions is recommended.**
#
# #### 1. Import the choice function of the random module.

# %%
import random

# %% [markdown]
# #### 2. Create a list that includes the 3 possible gesture options of the game: 'rock', 'paper' or 'scissors'. Store the list in a variable called `gestures`.

# %%
gestures = ['rock' , 'paper' , 'scissors']

# %% [markdown]
# #### 3. Create a variable called `n_rounds` to store the maximum number of rounds to play in a game.
# Remember that the number of rounds must be odd: 1, 3, 5, ...

# %%
n_rounds = 0

# %% [markdown]
# #### 4. Create a variable called `rounds_to_win` to store the number of rounds that a player must win to win the game.
# **Hint**: the value stored in `rounds_to_win` depends on the value of `n_rounds`.

# %%
rounds_to_win = 4

# %% [markdown]
# #### 5. Create two variables to store the number of rounds that the computer and the player have won. Call these variables `cpu_score` and `player_score`.

# %%
cpu_score = 0
player_score = 0

# %% [markdown]
# #### 6. Define a function that randomly returns one of the 3 gesture options.
# You will use this function to simulate the gesture choice of the computer.

# %%
 import random
    cpu = random.choice(gestures)
    print("The computer selected:", cpu, "\n")
    print("Player 1 -", options, "x", cpu, "- Computer")

# %% [markdown]
# #### 7. Define a function that asks the player which is the gesture he or she wants to show: 'rock', 'paper' or 'scissors'.
# The player should only be allowed to choose one of the 3 gesture options. If the player's choice is not rock, paper or scissors, keep asking until it is.

# %%
print("Welcome to the Rock, Paper and Scissors game!!!\n")
name = input("What is your name player 1?\n")
print("Hello", name, "!", "You are going to play against the Computer\n")
print("The battle has 7 rounds , the winner needs to win 4 times OR to have more victories than the opponent\n")
print("Lets start it ! Select rock, paper or scissors, DONT FORGET TO WRITE CORRECTLY\n")

options = input("Player 1 , what is your option? rock, paper or scissors?\n")

if options == 'rock' or options == 'paper' or options == 'scissors':
        print("Ok, your option is:", options)
        
elif options != 'rock' or options != 'paper' or options != 'scissors':
    while options != 'rock' or options != 'paper' or options != 'scissors': 
        print("Ops, we dont have this option...try again writing correctly\n") 
        options = input("Player_1, what is your option?\n")
        if options == 'rock' or options == 'paper' or options == 'scissors':
            print("Ok, your option is:", options)
            break
# Out:
# Welcome to the Rock, Paper and Scissors game!!!
#
# What is your name player 1?
# Edu
# Hello Edu ! You are going to play against the Computer
#
# The battle has 7 rounds , the winner needs to win 4 times OR to have more victories than the opponent
#
# Lets start it ! Select rock, paper or scissors, DONT FORGET TO WRITE CORRECTLY
#
# Player 1 , what is your option? rock, paper or scissors?
# rock
# Ok, your option is: rock

# %% [markdown]
# #### 8. Define a function that checks who won a round.
# The function should return 0 if there is a tie, 1 if the computer wins and 2 if the player wins.

# %%
#example

if options == 'rock' and cpu == 'paper':
        print("Paper covers rock! ", "Round", n_rounds, ":", "The computer won this round!!!")
        cpu_score += 1
        print("The computer score is:", cpu_score, "\n")
        print("------------------------------------------------------------")
        if cpu_score == rounds_to_win:
            print("Stop! The computer achieved 4 wins, its the CHAMPION!")
            break

# %% [markdown]
# #### 9. Define a function that prints the choice of the computer, the choice of the player and a message that announces who won the current round.
# You should also use this function to update the variables that count the number of rounds that the computer and the player have won. The score of the winner increases by one point. If there is a tie, the score does not increase.

# %%
while n_rounds < 7:
     
    if options == cpu:
        n_rounds += 1
        print("Round", n_rounds, ":", "TIE!!! 0 POINTS FOR THE PLAYERS\n")
        print("------------------------------------------------------------")
         
    elif options != cpu:
        n_rounds += 1 

        if options == 'rock' and cpu == 'paper':
        
            print("Paper covers rock! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break

        elif options == 'rock' and cpu == 'scissors':
        
            print("Rock smashes scissors! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'paper' and cpu == 'rock':
        
            print("Paper covers rock! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'paper' and cpu == 'scissors':
        
            print("Scissors cuts paper! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1 
            print("The computer score is:", cpu_score, "\n")
            print("------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break
        
        elif options == 'scissors' and cpu == 'paper':
        
            print("Scissors cuts paper! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'scissors' and cpu == 'rock':
        
            print("Rock smashes scissors! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break

# %% [markdown]
# #### 10. Now it's time to code the execution of the game using the functions and variables you defined above.
#
# First, create a loop structure that repeats while no player reaches the minimum score necessary to win and the number of rounds is less than the maximum number of rounds to play in a game.
#
# Inside the loop, use the functions and variables above to create the execution of a round: ask for the player's choice, generate the random choice of the computer, show the round results, update the scores, etc.

# %%
print("Welcome to the Rock, Paper and Scissors game!!!\n")
name = input("What is your name player 1?\n")
print("Hello", name, "!", "You are going to play against the Computer\n")
print("The battle has 7 rounds , the winner needs to win 4 times OR to have more victories than the opponent\n")
print("Lets start it ! Select rock, paper or scissors, DONT FORGET TO WRITE CORRECTLY\n")

gestures = ['rock' , 'paper' , 'scissors']

print("How many rounds do you want to play?")

n_rounds = 0
rounds_to_win = 4
cpu_score = 0
player_score = 0   
    
while n_rounds < 7:
    
    options = input("Player 1 , what is your option? rock, paper or scissors?\n")

    if options == 'rock' or options == 'paper' or options == 'scissors':
        print("Ok, your option is:", options)
        
    elif options != 'rock' or options != 'paper' or options != 'scissors':
        while options != 'rock' or options != 'paper' or options != 'scissors': 
            print("Ops, we dont have this option...try again writing correctly\n") 
            options = input("Player_1, what is your option?\n")
            if options == 'rock' or options == 'paper' or options == 'scissors':
                print("Ok, your option is:", options)
                break      
            
    import random
    cpu = random.choice(gestures)
    print("The computer selected:", cpu, "\n")
    print("Player 1 -", options, "x", cpu, "- Computer")
     
    if options == cpu:
        n_rounds += 1
        print("Round", n_rounds, ":", "TIE!!! 0 POINTS FOR THE PLAYERS\n")
        print("------------------------------------------------------------")
         
    elif options != cpu:
        n_rounds += 1 

        if options == 'rock' and cpu == 'paper':
        
            print("Paper covers rock! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break

        elif options == 'rock' and cpu == 'scissors':
        
            print("Rock smashes scissors! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'paper' and cpu == 'rock':
        
            print("Paper covers rock! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'paper' and cpu == 'scissors':
        
            print("Scissors cuts paper! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1 
            print("The computer score is:", cpu_score, "\n")
            print("------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break
        
        elif options == 'scissors' and cpu == 'paper':
        
            print("Scissors cuts paper! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'scissors' and cpu == 'rock':
        
            print("Rock smashes scissors! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break

    if n_rounds == 7:
        if cpu_score < rounds_to_win and player_score < rounds_to_win:
            if player_score > cpu_score:
                print(name, "is the CHAMPION with more scores!!!")
            elif cpu_score > player_score: 
                print("The computer is the CHAMPION with more scores!!!")
            else:
                print("We dont have a champion today...")
# Out:
# Welcome to the Rock, Paper and Scissors game!!!
#
# What is your name player 1?
# Eduardo
# Hello Eduardo ! You are going to play against the Computer
#
# The battle has 7 rounds , the winner needs to win 4 times OR to have more victories than the opponent
#
# Lets start it ! Select rock, paper or scissors, DONT FORGET TO WRITE CORRECTLY
#
# How many rounds do you want to play?
# Player 1 , what is your option? rock, paper or scissors?
# rock
# Ok, your option is: rock
# The computer selected: rock
#
# Player 1 - rock x rock - Computer
# Round 1 : TIE!!! 0 POINTS FOR THE PLAYERS
#
# ------------------------------------------------------------
# Player 1 , what is your option? rock, paper or scissors?
# paper
# Ok, your option is: paper
# The computer selected: paper
#
# Player 1 - paper x paper - Computer
# Round 2 : TIE!!! 0 POINTS FOR THE PLAYERS
#
# ------------------------------------------------------------
# Player 1 , what is your option? rock, paper or scissors?
# scissors
# ...

# %% [markdown]
# #### 11. Print the winner of the game based on who won more rounds.
# Remember that the game might be tied.

# %%
if n_rounds == 7:
        if cpu_score < rounds_to_win and player_score < rounds_to_win:
            if player_score > cpu_score:
                print(name, "is the CHAMPION with more scores!!!")
            elif cpu_score > player_score: 
                print("The computer is the CHAMPION with more scores!!!")
            else:
                print("We dont have a champion today...")

# %% [markdown]
# # Bonus: Rock, Paper, Scissors, Lizard & Spock
# ![](images/rpsls.jpg)
#
# In this challenge, you need to improve the previous game by adding two new options. To know more about the rules of the improved version of rock, paper, scissors, check this [link](http://www.samkass.com/theories/RPSSL.html).
#
# In addition, you will also need to improve how the game interacts with the player: the number of rounds to play, which must be an odd number, will be requested to the user until a valid number is entered. Define a new function to make that request.
#
# **Hint**: Try to reuse the code that you already coded in the previous challenge. If your code is efficient, this bonus will only consist of simple modifications to the original game.

# %%
print("Welcome to the Rock, Paper, Scissors, Lizard & Spock game!!!\n")
name = input("What is your name player 1?\n")
print("Hello", name, "!", "You are going to play against the Computer\n")
print("The battle has 7 rounds , the winner needs to win 4 times OR to have more victories than the opponent\n")
print("Lets start it ! Select rock, paper, scissors, lizard or spock DONT FORGET TO WRITE CORRECTLY\n")

gestures = ['rock' , 'paper' , 'scissors', 'lizard', 'spock']
   
n_rounds = 0
rounds_to_win = 4
cpu_score = 0
player_score = 0   

n_rounds = 0
rounds_to_win = 4
cpu_score = 0
player_score = 0   
    
while n_rounds < 7:
    
    options = input("Player_1, what is your option? rock, paper, scissors, lizard or spock?\n")

    if options == 'rock' or options == 'paper' or options == 'scissors' or options == 'lizard' or options == 'spock':
        print("Ok, your option is:", options)
    
    elif options != 'rock' or options != 'paper' or options != 'scissors' or options != 'lizard' or options != 'spock':
        
        while options != 'rock' or options != 'paper' or options != 'scissors' or options != 'lizard' or options != 'spock': 
            print("Ops, we dont have this option...try again writing correctly\n") 
            options = input("Player_1, what is your option?\n")
            if options == 'rock' or options == 'paper' or options == 'scissors' or options == 'lizard' or options == 'spock':
                print("Ok, your option is:", options)
                break      
            
    import random
    cpu = random.choice(gestures)
    print("The computer selected:", cpu, "\n")
    print("Player 1 -", options, "x", cpu, "- Computer")
     
    if options == cpu:
        n_rounds += 1
        print("Round", n_rounds, ":", "TIE!!! 0 POINTS FOR THE PLAYERS\n")
        print("---------------------------------------------------------------")
    
    elif options != cpu:
        n_rounds += 1 

        if options == 'rock' and cpu == 'paper':
        
            print("Paper covers rock! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break

        elif options == 'rock' and cpu == 'lizard':
        
            print("Rock crushes lizard! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break        
                
        elif options == 'rock' and cpu == 'spock':
        
            print("Spock vaporizes rock! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break             
     
        elif options == 'rock' and cpu == 'scissors':
        
            print("Rock smashes scissors! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
                
        elif options == 'paper' and cpu == 'rock':
        
            print("Paper covers rock! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'paper' and cpu == 'scissors':
        
            print("Scissors cuts paper! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1 
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, it is the CHAMPION!")
                break
        
        elif options == 'paper' and cpu == 'spock':
        
            print("Paper disproves spock!", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break             
            
        elif options == 'paper' and cpu == 'lizard':
        
            print("Lizard eats paper!", "Round", n_rounds, ":", "the computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, it is the CHAMPION!")
                break
                
        elif options == 'scissors' and cpu == 'paper':
        
            print("Scissors cuts paper! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
        
        elif options == 'scissors' and cpu == 'rock':
        
            print("Rock smashes scissors! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break
                
        elif options == 'scissors' and cpu == 'spock':
        
            print("Spock smashes scissors!", "Round", n_rounds, ":", "the computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, here we have the CHAMPION!")
                break             
            
        elif options == 'scissors' and cpu == 'lizard':
        
            print("Scissors decapitates lizard!", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break    
                
        elif options == 'lizard' and cpu == 'rock':
            
            print("Rock crushes lizard! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break
                
                
        elif options == 'lizard' and cpu == 'paper':
            print("Lizard eats paper! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
                
            
        elif options == 'lizard' and cpu == 'scissors':
            print("Scissors decapitates lizard! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break
            
        elif options == 'lizard' and cpu == 'spock':
            print("Lizard posions spock! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name,  "achieved 4 wins, here we have the CHAMPION!")
                break          
                
        elif options == 'spock' and cpu == 'rock':
            
            print("Spock vaporizes rock! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break
                
        elif options == 'spock' and cpu == 'paper':
            print("Paper disproves spock! ", "Round", n_rounds, ":", "the computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break
                
        elif options == 'spock' and cpu == 'scissors':
            print("Spock smashes scissors! ", "Round", n_rounds, ":", name, "won this round!!!")
            player_score += 1
            print(name, "score is:", player_score, "\n")
            print("---------------------------------------------------------------")
            if player_score == rounds_to_win:
                print("Stop!", name, "achieved 4 wins, here we have the CHAMPION!")
                break  
              
        elif options == 'spock' and cpu == 'lizard':
            print("Lizard poisons spock! ", "Round", n_rounds, ":", "The computer won this round!!!")
            cpu_score += 1
            print("The computer score is:", cpu_score, "\n")
            print("---------------------------------------------------------------")
            if cpu_score == rounds_to_win:
                print("Stop! The computer achieved 4 wins, its the CHAMPION!")
                break                     
                
    if n_rounds == 7:
        if cpu_score < rounds_to_win and player_score < rounds_to_win:
            if player_score > cpu_score:
                print(name, "is the CHAMPION with more socres!!!")
            elif cpu_score > player_score: 
                print("The computer is the CHAMPION with more scores!!!")
            else:
                print("We dont have a champion today...")
# Out:
# Welcome to the Rock, Paper, Scissors, Lizard & Spock game!!!
#
# What is your name player 1?
# Eduardo
# Hello Eduardo ! You are going to play against the Computer
#
# The battle has 7 rounds , the winner needs to win 4 times OR to have more victories than the opponent
#
# Lets start it ! Select rock, paper, scissors, lizard or spock DONT FORGET TO WRITE CORRECTLY
#
# Player_1, what is your option? rock, paper, scissors, lizard or spock?
# lizard
# Ok, your option is: lizard
# The computer selected: rock
#
# Player 1 - lizard x rock - Computer
# Rock crushes lizard!  Round 1 : The computer won this round!!!
# The computer score is: 1
#
# ---------------------------------------------------------------
# Player_1, what is your option? rock, paper, scissors, lizard or spock?
# spock
# Ok, your option is: spock
# The computer selected: rock
#
# Player 1 - spock x rock - Computer
# Spock vaporizes rock!  Round 2 : Eduardo won this round!!!
# Eduardo score is: 1
#
# ...
